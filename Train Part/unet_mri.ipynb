# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
#Set Parameters
im_width = 256
im_height = 256

# %% [markdown]
# # **Load image's path and mask's path**

# %%
train_files = []
mask_files = glob('lgg-mri-segmentation/kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_8.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_9.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_2.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_3.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_20.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_15.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_14.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_18.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_19.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_12.tif']
# ['lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_8_mask.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_9_mask.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_2_mask.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_3_mask.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_20_mask.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_15_mask.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_14_mask.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_18_mask.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_19_mask.tif', 'lgg-mri-segmentation/kaggle_3m/TCGA_CS_6667_20011105/TCGA_CS_6667_20011105_12_mask.tif']

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
   
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def jac_distance(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)

    return - iou(y_true, y_pred)

# %% [markdown]
# # **Unet**

# %%
def unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(64, (3, 3), padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, (3, 3), padding='same')(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = Conv2D(128, (3, 3), padding='same')(pool1)
    bn2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, (3, 3), padding='same')(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = Conv2D(256, (3, 3), padding='same')(pool2)
    bn3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, (3, 3), padding='same')(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = Conv2D(512, (3, 3), padding='same')(pool3)
    bn4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, (3, 3), padding='same')(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(1024, (3, 3), padding='same')(pool4)
    bn5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, (3, 3), padding='same')(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation('relu')(bn5)

    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, (3, 3), padding='same')(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation('relu')(bn6)

    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, (3, 3), padding='same')(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation('relu')(bn7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, (3, 3), padding='same')(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation('relu')(bn8)

    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, (3, 3), padding='same')(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation('relu')(bn9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
model = unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  alization)                     )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['conv2d_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_1[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  activation_8 (Activation)      (None, 16, 16, 1024  0           ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 512)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_11 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 256)  0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_13 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  activation_14 (Activation)     (None, 128, 128, 12  0           ['conv2d_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 12  512        ['conv2d_15[0][0]']
#  rmalization)                   8)
#
#  activation_15 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_7[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 256, 256, 64  0           ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 64  256        ['conv2d_17[0][0]']
#  rmalization)                   )
#
#  activation_17 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,043,521
# Trainable params: 31,037,633
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# # **Training**

# %%
EPOCHS = 51
BATCH_SIZE = 32
learning_rate = 1e-4

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))
    
test_gener = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
    
model = unet(input_size=(im_height, im_width, 3))



decay_rate = learning_rate / EPOCHS
opt = tf.keras.optimizers.legacy.Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=decay_rate, amsgrad=False)
model.compile(optimizer=opt, loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

callbacks = [ModelCheckpoint('unet_brain_mri_seg.hdf5', verbose=1, save_best_only=True)]

history = model.fit(train_gen,
                    steps_per_epoch=len(df_train) / BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data = test_gener,
                    validation_steps=len(df_val) / BATCH_SIZE)
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# /Users/gokaydindar/anaconda3/envs/bitirme5/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/51
# 2023-06-07 23:57:00.539825: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 89/88 [==============================] - ETA: -11s - loss: -0.1008 - binary_accuracy: 0.9083 - iou: 0.0537 - dice_coef: 0.1004Found 708 validated image filenames.
# Found 708 validated image filenames.
#
# Epoch 1: val_loss improved from inf to -0.02115, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1799s 20s/step - loss: -0.1008 - binary_accuracy: 0.9083 - iou: 0.0537 - dice_coef: 0.1004 - val_loss: -0.0211 - val_binary_accuracy: 0.9894 - val_iou: 0.0113 - val_dice_coef: 0.0221
# Epoch 2/51
# 89/88 [==============================] - ETA: -11s - loss: -0.1728 - binary_accuracy: 0.9844 - iou: 0.0958 - dice_coef: 0.1728
# Epoch 2: val_loss improved from -0.02115 to -0.03626, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1796s 20s/step - loss: -0.1728 - binary_accuracy: 0.9844 - iou: 0.0958 - dice_coef: 0.1728 - val_loss: -0.0363 - val_binary_accuracy: 0.9912 - val_iou: 0.0183 - val_dice_coef: 0.0354
# Epoch 3/51
# 89/88 [==============================] - ETA: -11s - loss: -0.2240 - binary_accuracy: 0.9887 - iou: 0.1276 - dice_coef: 0.2234
# Epoch 3: val_loss improved from -0.03626 to -0.09323, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1811s 20s/step - loss: -0.2240 - binary_accuracy: 0.9887 - iou: 0.1276 - dice_coef: 0.2234 - val_loss: -0.0932 - val_binary_accuracy: 0.9917 - val_iou: 0.0525 - val_dice_coef: 0.0979
# Epoch 4/51
# 89/88 [==============================] - ETA: -11s - loss: -0.2724 - binary_accuracy: 0.9903 - iou: 0.1600 - dice_coef: 0.2720
# Epoch 4: val_loss did not improve from -0.09323
# 88/88 [==============================] - 1809s 20s/step - loss: -0.2724 - binary_accuracy: 0.9903 - iou: 0.1600 - dice_coef: 0.2720 - val_loss: -0.0683 - val_binary_accuracy: 0.7325 - val_iou: 0.0358 - val_dice_coef: 0.0688
# Epoch 5/51
# 89/88 [==============================] - ETA: -11s - loss: -0.3247 - binary_accuracy: 0.9917 - iou: 0.1962 - dice_coef: 0.3236
# Epoch 5: val_loss improved from -0.09323 to -0.29033, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1834s 21s/step - loss: -0.3247 - binary_accuracy: 0.9917 - iou: 0.1962 - dice_coef: 0.3236 - val_loss: -0.2903 - val_binary_accuracy: 0.9880 - val_iou: 0.1694 - val_dice_coef: 0.2858
# Epoch 6/51
# 89/88 [==============================] - ETA: -12s - loss: -0.3906 - binary_accuracy: 0.9935 - iou: 0.2462 - dice_coef: 0.3902
# Epoch 6: val_loss improved from -0.29033 to -0.37802, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1853s 21s/step - loss: -0.3906 - binary_accuracy: 0.9935 - iou: 0.2462 - dice_coef: 0.3902 - val_loss: -0.3780 - val_binary_accuracy: 0.9889 - val_iou: 0.2385 - val_dice_coef: 0.3786
# Epoch 7/51
# 89/88 [==============================] - ETA: -12s - loss: -0.4540 - binary_accuracy: 0.9945 - iou: 0.2981 - dice_coef: 0.4525
# Epoch 7: val_loss improved from -0.37802 to -0.47518, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1977s 22s/step - loss: -0.4540 - binary_accuracy: 0.9945 - iou: 0.2981 - dice_coef: 0.4525 - val_loss: -0.4752 - val_binary_accuracy: 0.9955 - val_iou: 0.3192 - val_dice_coef: 0.4775
# Epoch 8/51
# 89/88 [==============================] - ETA: -12s - loss: -0.5160 - binary_accuracy: 0.9948 - iou: 0.3527 - dice_coef: 0.5152
# Epoch 8: val_loss improved from -0.47518 to -0.52432, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1972s 22s/step - loss: -0.5160 - binary_accuracy: 0.9948 - iou: 0.3527 - dice_coef: 0.5152 - val_loss: -0.5243 - val_binary_accuracy: 0.9934 - val_iou: 0.3590 - val_dice_coef: 0.5253
# Epoch 9/51
# 89/88 [==============================] - ETA: -12s - loss: -0.5779 - binary_accuracy: 0.9957 - iou: 0.4115 - dice_coef: 0.5777
# Epoch 9: val_loss did not improve from -0.52432
# 88/88 [==============================] - 1975s 22s/step - loss: -0.5779 - binary_accuracy: 0.9957 - iou: 0.4115 - dice_coef: 0.5777 - val_loss: -0.5185 - val_binary_accuracy: 0.9954 - val_iou: 0.3673 - val_dice_coef: 0.5283
# Epoch 10/51
# 89/88 [==============================] - ETA: -12s - loss: -0.6107 - binary_accuracy: 0.9957 - iou: 0.4475 - dice_coef: 0.6117
# Epoch 10: val_loss improved from -0.52432 to -0.67213, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1963s 22s/step - loss: -0.6107 - binary_accuracy: 0.9957 - iou: 0.4475 - dice_coef: 0.6117 - val_loss: -0.6721 - val_binary_accuracy: 0.9961 - val_iou: 0.5169 - val_dice_coef: 0.6773
# Epoch 11/51
# 89/88 [==============================] - ETA: -12s - loss: -0.6691 - binary_accuracy: 0.9964 - iou: 0.5087 - dice_coef: 0.6682
# Epoch 11: val_loss did not improve from -0.67213
# 88/88 [==============================] - 1963s 22s/step - loss: -0.6691 - binary_accuracy: 0.9964 - iou: 0.5087 - dice_coef: 0.6682 - val_loss: -0.6458 - val_binary_accuracy: 0.9965 - val_iou: 0.4885 - val_dice_coef: 0.6504
# Epoch 12/51
# 89/88 [==============================] - ETA: -12s - loss: -0.6970 - binary_accuracy: 0.9966 - iou: 0.5429 - dice_coef: 0.6970
# Epoch 12: val_loss improved from -0.67213 to -0.74388, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1949s 22s/step - loss: -0.6970 - binary_accuracy: 0.9966 - iou: 0.5429 - dice_coef: 0.6970 - val_loss: -0.7439 - val_binary_accuracy: 0.9968 - val_iou: 0.5979 - val_dice_coef: 0.7443
# Epoch 13/51
# 89/88 [==============================] - ETA: -12s - loss: -0.7231 - binary_accuracy: 0.9967 - iou: 0.5733 - dice_coef: 0.7238
# Epoch 13: val_loss improved from -0.74388 to -0.76246, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1957s 22s/step - loss: -0.7231 - binary_accuracy: 0.9967 - iou: 0.5733 - dice_coef: 0.7238 - val_loss: -0.7625 - val_binary_accuracy: 0.9969 - val_iou: 0.6006 - val_dice_coef: 0.7359
# Epoch 14/51
# 89/88 [==============================] - ETA: -12s - loss: -0.7374 - binary_accuracy: 0.9966 - iou: 0.5890 - dice_coef: 0.7365
# Epoch 14: val_loss did not improve from -0.76246
# 88/88 [==============================] - 1944s 22s/step - loss: -0.7374 - binary_accuracy: 0.9966 - iou: 0.5890 - dice_coef: 0.7365 - val_loss: -0.7081 - val_binary_accuracy: 0.9958 - val_iou: 0.5628 - val_dice_coef: 0.7149
# Epoch 15/51
# 89/88 [==============================] - ETA: -11s - loss: -0.7687 - binary_accuracy: 0.9970 - iou: 0.6292 - dice_coef: 0.7688
# Epoch 15: val_loss did not improve from -0.76246
# 88/88 [==============================] - 1777s 20s/step - loss: -0.7687 - binary_accuracy: 0.9970 - iou: 0.6292 - dice_coef: 0.7688 - val_loss: -0.7363 - val_binary_accuracy: 0.9967 - val_iou: 0.5949 - val_dice_coef: 0.7411
# Epoch 16/51
# 89/88 [==============================] - ETA: -11s - loss: -0.7772 - binary_accuracy: 0.9971 - iou: 0.6418 - dice_coef: 0.7778
# Epoch 16: val_loss improved from -0.76246 to -0.78554, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1807s 20s/step - loss: -0.7772 - binary_accuracy: 0.9971 - iou: 0.6418 - dice_coef: 0.7778 - val_loss: -0.7855 - val_binary_accuracy: 0.9972 - val_iou: 0.6595 - val_dice_coef: 0.7910
# Epoch 17/51
# 89/88 [==============================] - ETA: -11s - loss: -0.7902 - binary_accuracy: 0.9972 - iou: 0.6593 - dice_coef: 0.7907
# Epoch 17: val_loss improved from -0.78554 to -0.82533, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1811s 21s/step - loss: -0.7902 - binary_accuracy: 0.9972 - iou: 0.6593 - dice_coef: 0.7907 - val_loss: -0.8253 - val_binary_accuracy: 0.9974 - val_iou: 0.6924 - val_dice_coef: 0.8039
# Epoch 18/51
# 89/88 [==============================] - ETA: -11s - loss: -0.7902 - binary_accuracy: 0.9970 - iou: 0.6591 - dice_coef: 0.7904
# Epoch 18: val_loss did not improve from -0.82533
# 88/88 [==============================] - 1753s 20s/step - loss: -0.7902 - binary_accuracy: 0.9970 - iou: 0.6591 - dice_coef: 0.7904 - val_loss: -0.7944 - val_binary_accuracy: 0.9963 - val_iou: 0.6683 - val_dice_coef: 0.7989
# Epoch 19/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8098 - binary_accuracy: 0.9972 - iou: 0.6857 - dice_coef: 0.8101
# Epoch 19: val_loss improved from -0.82533 to -0.82559, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1717s 19s/step - loss: -0.8098 - binary_accuracy: 0.9972 - iou: 0.6857 - dice_coef: 0.8101 - val_loss: -0.8256 - val_binary_accuracy: 0.9974 - val_iou: 0.7140 - val_dice_coef: 0.8300
# Epoch 20/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8169 - binary_accuracy: 0.9973 - iou: 0.6964 - dice_coef: 0.8172
# Epoch 20: val_loss did not improve from -0.82559
# 88/88 [==============================] - 1725s 20s/step - loss: -0.8169 - binary_accuracy: 0.9973 - iou: 0.6964 - dice_coef: 0.8172 - val_loss: -0.8190 - val_binary_accuracy: 0.9973 - val_iou: 0.7006 - val_dice_coef: 0.8209
# Epoch 21/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8287 - binary_accuracy: 0.9975 - iou: 0.7138 - dice_coef: 0.8287
# Epoch 21: val_loss improved from -0.82559 to -0.84908, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1729s 20s/step - loss: -0.8287 - binary_accuracy: 0.9975 - iou: 0.7138 - dice_coef: 0.8287 - val_loss: -0.8491 - val_binary_accuracy: 0.9974 - val_iou: 0.7445 - val_dice_coef: 0.8514
# Epoch 22/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8329 - binary_accuracy: 0.9974 - iou: 0.7167 - dice_coef: 0.8320
# Epoch 22: val_loss did not improve from -0.84908
# 88/88 [==============================] - 1737s 20s/step - loss: -0.8329 - binary_accuracy: 0.9974 - iou: 0.7167 - dice_coef: 0.8320 - val_loss: -0.8371 - val_binary_accuracy: 0.9973 - val_iou: 0.7269 - val_dice_coef: 0.8399
# Epoch 23/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8308 - binary_accuracy: 0.9973 - iou: 0.7150 - dice_coef: 0.8312
# Epoch 23: val_loss did not improve from -0.84908
# 88/88 [==============================] - 1733s 20s/step - loss: -0.8308 - binary_accuracy: 0.9973 - iou: 0.7150 - dice_coef: 0.8312 - val_loss: -0.7989 - val_binary_accuracy: 0.9969 - val_iou: 0.6763 - val_dice_coef: 0.7988
# Epoch 24/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8270 - binary_accuracy: 0.9972 - iou: 0.7092 - dice_coef: 0.8257
# Epoch 24: val_loss did not improve from -0.84908
# 88/88 [==============================] - 1736s 20s/step - loss: -0.8270 - binary_accuracy: 0.9972 - iou: 0.7092 - dice_coef: 0.8257 - val_loss: -0.6807 - val_binary_accuracy: 0.9923 - val_iou: 0.5360 - val_dice_coef: 0.6885
# Epoch 25/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8216 - binary_accuracy: 0.9972 - iou: 0.7035 - dice_coef: 0.8218
# Epoch 25: val_loss improved from -0.84908 to -0.86021, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1760s 20s/step - loss: -0.8216 - binary_accuracy: 0.9972 - iou: 0.7035 - dice_coef: 0.8218 - val_loss: -0.8602 - val_binary_accuracy: 0.9974 - val_iou: 0.7565 - val_dice_coef: 0.8601
# Epoch 26/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8413 - binary_accuracy: 0.9974 - iou: 0.7283 - dice_coef: 0.8399
# Epoch 26: val_loss did not improve from -0.86021
# 88/88 [==============================] - 1819s 21s/step - loss: -0.8413 - binary_accuracy: 0.9974 - iou: 0.7283 - dice_coef: 0.8399 - val_loss: -0.8367 - val_binary_accuracy: 0.9970 - val_iou: 0.7308 - val_dice_coef: 0.8408
# Epoch 27/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8455 - binary_accuracy: 0.9975 - iou: 0.7356 - dice_coef: 0.8444
# Epoch 27: val_loss improved from -0.86021 to -0.86764, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1827s 21s/step - loss: -0.8455 - binary_accuracy: 0.9975 - iou: 0.7356 - dice_coef: 0.8444 - val_loss: -0.8676 - val_binary_accuracy: 0.9979 - val_iou: 0.7735 - val_dice_coef: 0.8705
# Epoch 28/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8525 - binary_accuracy: 0.9975 - iou: 0.7459 - dice_coef: 0.8521
# Epoch 28: val_loss improved from -0.86764 to -0.87574, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1833s 21s/step - loss: -0.8525 - binary_accuracy: 0.9975 - iou: 0.7459 - dice_coef: 0.8521 - val_loss: -0.8757 - val_binary_accuracy: 0.9977 - val_iou: 0.7737 - val_dice_coef: 0.8633
# Epoch 29/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8559 - binary_accuracy: 0.9976 - iou: 0.7527 - dice_coef: 0.8562
# Epoch 29: val_loss did not improve from -0.87574
# 88/88 [==============================] - 1834s 21s/step - loss: -0.8559 - binary_accuracy: 0.9976 - iou: 0.7527 - dice_coef: 0.8562 - val_loss: -0.8630 - val_binary_accuracy: 0.9974 - val_iou: 0.7610 - val_dice_coef: 0.8630
# Epoch 30/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8525 - binary_accuracy: 0.9975 - iou: 0.7471 - dice_coef: 0.8528
# Epoch 30: val_loss did not improve from -0.87574
# 88/88 [==============================] - 1840s 21s/step - loss: -0.8525 - binary_accuracy: 0.9975 - iou: 0.7471 - dice_coef: 0.8528 - val_loss: -0.8637 - val_binary_accuracy: 0.9977 - val_iou: 0.7623 - val_dice_coef: 0.8628
# Epoch 31/51
# 89/88 [==============================] - ETA: -12s - loss: -0.8597 - binary_accuracy: 0.9976 - iou: 0.7591 - dice_coef: 0.8601
# Epoch 31: val_loss did not improve from -0.87574
# 88/88 [==============================] - 1848s 21s/step - loss: -0.8597 - binary_accuracy: 0.9976 - iou: 0.7591 - dice_coef: 0.8601 - val_loss: -0.8565 - val_binary_accuracy: 0.9970 - val_iou: 0.7557 - val_dice_coef: 0.8593
# Epoch 32/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8653 - binary_accuracy: 0.9977 - iou: 0.7666 - dice_coef: 0.8655
# Epoch 32: val_loss did not improve from -0.87574
# 88/88 [==============================] - 1840s 21s/step - loss: -0.8653 - binary_accuracy: 0.9977 - iou: 0.7666 - dice_coef: 0.8655 - val_loss: -0.8721 - val_binary_accuracy: 0.9977 - val_iou: 0.7710 - val_dice_coef: 0.8665
# Epoch 33/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8637 - binary_accuracy: 0.9977 - iou: 0.7642 - dice_coef: 0.8639
# Epoch 33: val_loss did not improve from -0.87574
# 88/88 [==============================] - 1843s 21s/step - loss: -0.8637 - binary_accuracy: 0.9977 - iou: 0.7642 - dice_coef: 0.8639 - val_loss: -0.8615 - val_binary_accuracy: 0.9979 - val_iou: 0.7664 - val_dice_coef: 0.8644
# Epoch 34/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8662 - binary_accuracy: 0.9977 - iou: 0.7710 - dice_coef: 0.8663
# Epoch 34: val_loss did not improve from -0.87574
# 88/88 [==============================] - 1842s 21s/step - loss: -0.8662 - binary_accuracy: 0.9977 - iou: 0.7710 - dice_coef: 0.8663 - val_loss: -0.8341 - val_binary_accuracy: 0.9967 - val_iou: 0.7146 - val_dice_coef: 0.8310
# Epoch 35/51
# 89/88 [==============================] - ETA: -12s - loss: -0.8685 - binary_accuracy: 0.9977 - iou: 0.7715 - dice_coef: 0.8684
# Epoch 35: val_loss did not improve from -0.87574
# 88/88 [==============================] - 1848s 21s/step - loss: -0.8685 - binary_accuracy: 0.9977 - iou: 0.7715 - dice_coef: 0.8684 - val_loss: -0.8484 - val_binary_accuracy: 0.9973 - val_iou: 0.7474 - val_dice_coef: 0.8500
# Epoch 36/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8702 - binary_accuracy: 0.9977 - iou: 0.7727 - dice_coef: 0.8695
# Epoch 36: val_loss improved from -0.87574 to -0.89417, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1836s 21s/step - loss: -0.8702 - binary_accuracy: 0.9977 - iou: 0.7727 - dice_coef: 0.8695 - val_loss: -0.8942 - val_binary_accuracy: 0.9980 - val_iou: 0.8139 - val_dice_coef: 0.8960
# Epoch 37/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8740 - binary_accuracy: 0.9978 - iou: 0.7804 - dice_coef: 0.8743
# Epoch 37: val_loss did not improve from -0.89417
# 88/88 [==============================] - 1835s 21s/step - loss: -0.8740 - binary_accuracy: 0.9978 - iou: 0.7804 - dice_coef: 0.8743 - val_loss: -0.8325 - val_binary_accuracy: 0.9971 - val_iou: 0.7169 - val_dice_coef: 0.8314
# Epoch 38/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8598 - binary_accuracy: 0.9976 - iou: 0.7587 - dice_coef: 0.8598
# Epoch 38: val_loss did not improve from -0.89417
# 88/88 [==============================] - 1837s 21s/step - loss: -0.8598 - binary_accuracy: 0.9976 - iou: 0.7587 - dice_coef: 0.8598 - val_loss: -0.8682 - val_binary_accuracy: 0.9976 - val_iou: 0.7744 - val_dice_coef: 0.8707
# Epoch 39/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8666 - binary_accuracy: 0.9977 - iou: 0.7695 - dice_coef: 0.8671
# Epoch 39: val_loss did not improve from -0.89417
# 88/88 [==============================] - 1814s 21s/step - loss: -0.8666 - binary_accuracy: 0.9977 - iou: 0.7695 - dice_coef: 0.8671 - val_loss: -0.8695 - val_binary_accuracy: 0.9975 - val_iou: 0.7672 - val_dice_coef: 0.8656
# Epoch 40/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8757 - binary_accuracy: 0.9978 - iou: 0.7830 - dice_coef: 0.8761
# Epoch 40: val_loss did not improve from -0.89417
# 88/88 [==============================] - 1712s 19s/step - loss: -0.8757 - binary_accuracy: 0.9978 - iou: 0.7830 - dice_coef: 0.8761 - val_loss: -0.8798 - val_binary_accuracy: 0.9976 - val_iou: 0.7885 - val_dice_coef: 0.8797
# Epoch 41/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8775 - binary_accuracy: 0.9978 - iou: 0.7843 - dice_coef: 0.8772
# Epoch 41: val_loss did not improve from -0.89417
# 88/88 [==============================] - 1711s 19s/step - loss: -0.8775 - binary_accuracy: 0.9978 - iou: 0.7843 - dice_coef: 0.8772 - val_loss: -0.8817 - val_binary_accuracy: 0.9979 - val_iou: 0.7911 - val_dice_coef: 0.8770
# Epoch 42/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8821 - binary_accuracy: 0.9979 - iou: 0.7922 - dice_coef: 0.8824
# Epoch 42: val_loss did not improve from -0.89417
# 88/88 [==============================] - 1718s 19s/step - loss: -0.8821 - binary_accuracy: 0.9979 - iou: 0.7922 - dice_coef: 0.8824 - val_loss: -0.8784 - val_binary_accuracy: 0.9977 - val_iou: 0.7838 - val_dice_coef: 0.8772
# Epoch 43/51
# 89/88 [==============================] - ETA: -12s - loss: -0.8726 - binary_accuracy: 0.9978 - iou: 0.7784 - dice_coef: 0.8730
# Epoch 43: val_loss improved from -0.89417 to -0.89665, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 1837s 21s/step - loss: -0.8726 - binary_accuracy: 0.9978 - iou: 0.7784 - dice_coef: 0.8730 - val_loss: -0.8966 - val_binary_accuracy: 0.9978 - val_iou: 0.8149 - val_dice_coef: 0.8935
# Epoch 44/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8789 - binary_accuracy: 0.9978 - iou: 0.7849 - dice_coef: 0.8769
# Epoch 44: val_loss did not improve from -0.89665
# 88/88 [==============================] - 1781s 20s/step - loss: -0.8789 - binary_accuracy: 0.9978 - iou: 0.7849 - dice_coef: 0.8769 - val_loss: -0.8247 - val_binary_accuracy: 0.9969 - val_iou: 0.7129 - val_dice_coef: 0.8282
# Epoch 45/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8757 - binary_accuracy: 0.9978 - iou: 0.7824 - dice_coef: 0.8757
# Epoch 45: val_loss did not improve from -0.89665
# 88/88 [==============================] - 1764s 20s/step - loss: -0.8757 - binary_accuracy: 0.9978 - iou: 0.7824 - dice_coef: 0.8757 - val_loss: -0.8847 - val_binary_accuracy: 0.9978 - val_iou: 0.7967 - val_dice_coef: 0.8855
# Epoch 46/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8800 - binary_accuracy: 0.9978 - iou: 0.7877 - dice_coef: 0.8794
# Epoch 46: val_loss did not improve from -0.89665
# 88/88 [==============================] - 1775s 20s/step - loss: -0.8800 - binary_accuracy: 0.9978 - iou: 0.7877 - dice_coef: 0.8794 - val_loss: -0.8838 - val_binary_accuracy: 0.9978 - val_iou: 0.7798 - val_dice_coef: 0.8694
# Epoch 47/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8769 - binary_accuracy: 0.9978 - iou: 0.7840 - dice_coef: 0.8767
# Epoch 47: val_loss did not improve from -0.89665
# 88/88 [==============================] - 1834s 21s/step - loss: -0.8769 - binary_accuracy: 0.9978 - iou: 0.7840 - dice_coef: 0.8767 - val_loss: -0.8851 - val_binary_accuracy: 0.9978 - val_iou: 0.7836 - val_dice_coef: 0.8722
# Epoch 48/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8823 - binary_accuracy: 0.9979 - iou: 0.7934 - dice_coef: 0.8828
# Epoch 48: val_loss did not improve from -0.89665
# 88/88 [==============================] - 1809s 20s/step - loss: -0.8823 - binary_accuracy: 0.9979 - iou: 0.7934 - dice_coef: 0.8828 - val_loss: -0.8882 - val_binary_accuracy: 0.9976 - val_iou: 0.8026 - val_dice_coef: 0.8897
# Epoch 49/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8836 - binary_accuracy: 0.9979 - iou: 0.7933 - dice_coef: 0.8820
# Epoch 49: val_loss did not improve from -0.89665
# 88/88 [==============================] - 1752s 20s/step - loss: -0.8836 - binary_accuracy: 0.9979 - iou: 0.7933 - dice_coef: 0.8820 - val_loss: -0.8790 - val_binary_accuracy: 0.9977 - val_iou: 0.7911 - val_dice_coef: 0.8814
# Epoch 50/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8892 - binary_accuracy: 0.9979 - iou: 0.8019 - dice_coef: 0.8887
# Epoch 50: val_loss did not improve from -0.89665
# 88/88 [==============================] - 1719s 19s/step - loss: -0.8892 - binary_accuracy: 0.9979 - iou: 0.8019 - dice_coef: 0.8887 - val_loss: -0.8818 - val_binary_accuracy: 0.9979 - val_iou: 0.7941 - val_dice_coef: 0.8832
# Epoch 51/51
# 89/88 [==============================] - ETA: -11s - loss: -0.8737 - binary_accuracy: 0.9977 - iou: 0.7798 - dice_coef: 0.8741
# Epoch 51: val_loss did not improve from -0.89665
# 88/88 [==============================] - 1721s 19s/step - loss: -0.8737 - binary_accuracy: 0.9977 - iou: 0.7798 - dice_coef: 0.8741 - val_loss: -0.8648 - val_binary_accuracy: 0.9972 - val_iou: 0.7622 - val_dice_coef: 0.8635

# %%
a = history.history

list_traindice = a['dice_coef']
list_testdice = a['val_dice_coef']

list_trainjaccard = a['iou']
list_testjaccard = a['val_iou']

list_trainloss = a['loss']
list_testloss = a['val_loss']
plt.figure(1)
plt.plot(list_testloss, 'b-')
plt.plot(list_trainloss,'r-')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('loss graph', fontsize = 15)
plt.figure(2)
plt.plot(list_traindice, 'r-')
plt.plot(list_testdice, 'b-')
plt.xlabel('iteration')
plt.ylabel('accuracy')
plt.title('accuracy graph', fontsize = 15)
plt.show()

# %%
model = load_model('unet_brain_mri_seg.hdf5', custom_objects={'dice_coef_loss': dice_coef_loss, 'iou': iou, 'dice_coef': dice_coef})

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
results = model.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
print("Test lost: ",results[0])
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 12/12 [==============================] - 69s 6s/step - loss: -0.8503 - binary_accuracy: 0.9968 - iou: 0.7448 - dice_coef: 0.8505
# Test lost:  -0.8502596616744995
# Test IOU:  0.996842622756958
# Test Dice Coefficent:  0.7447747588157654

# %%
for i in range(10):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[index])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 205ms/step
